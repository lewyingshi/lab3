# %% [markdown]
# <a href="https://colab.research.google.com/github/lewyingshi/lab3/blob/master/lab_3_functions_and_comprehensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 3 - Function and List Comprehension Exercises
#
# Please complete each exercise and submit your work on D2L.
#
# **Rules:**
#
# 1. All functions should be defined with `lambda` (only test functions should use `def` statements.)
# 2. Each function should be accompanied by test function that covers normal and edge cases.

# %% [markdown]
# ### <font color='red'> Exercise 1 </font>
#
# Write a function `sum_of_squares` that computes the sum of the squares of the numbers in the input list. *Use a helper function in your solution*
#
#
# **Example** `sum_of_squares([2, 3, 4]) === 4 + 9 + 16`  **HINT:** Use a comprehension to square the values and `sum` to compute the sum.

# %%
# !pip install composable
# Out:
# Collecting composable
#   Downloading https://files.pythonhosted.org/packages/d3/1a/87106d920e7533b86b7de59d4df02a36e7289618fbd51a5b837d090e1400/composable-0.1.3-py3-none-any.whl
# Requirement already satisfied: toolz<0.11.0,>=0.10.0 in /usr/local/lib/python3.6/dist-packages (from composable) (0.10.0)
# Collecting python-forge<19.0,>=18.6
#   Downloading https://files.pythonhosted.org/packages/41/d6/e9af8e22d153ebbf584833c1c96d590046f522ae2a86978d4efe496b4aac/python_forge-18.6.0-py35-none-any.whl
# Installing collected packages: python-forge, composable
# Successfully installed composable-0.1.3 python-forge-18.6.0

# %%
from composable import pipeable

# %%
# square root function
sq_root = lambda x: x**2
sq_root(8)
# Out:
# 64

# %%
# lambda function
sum_of_squares = lambda num: sum([sq_root(num) for num in num[:]])
sum_of_squares([2,3,4])
# Out:
# 29

# %%
# edge case
sum_of_squares([1])
# Out:
# 1

# %%
sum_of_squares(range(5))
# Out:
# 30

# %%
sum_of_squares([3,3,3])
# Out:
# 27

# %%
# helper function
sq_root = lambda x: x**2

# test function
def sum_of_sq(myList):
    """ Calculates the sum of the squares of the numbers in a list.

    Args:
        myList: A list of numbers

    Returns:
         A number that is the sum of all the numbers in a list that have been squared individually.

    """
    output = sum([sq_root(myList) for myList in myList[:]])
    return output

def test_sum_of_sq():
    assert sum_of_sq([1]) == 1
    assert sum_of_sq(range(5)) == 30
    assert sum_of_sq([3, 3, 3])
test_sum_of_sq()

# %% [markdown]
# ### <font color="red"> Exercise 2 </font>
#
# Write a function called `sum_even` that sums up all the even numbers in a list.  Include helper functions in your solution.
#
# **Example** `sum_even([1,2,3,4]) == 6`
#
# **Hint** You need a filter here.

# %%
# helper function
is_even = lambda x: x % 2 == 0
is_even(4)
# Out:
# True

# %%
is_even(3)
# Out:
# False

# %%
# lambda function
sum_even = lambda L: sum([L for L in list(L) if is_even(L)])

# %%
sum_even([1,2])
# Out:
# 2

# %%
sum_even([3,4,5,6])
# Out:
# 10

# %%
sum_even([1,2,3,4])
# Out:
# 6

# %%
sum_even(range(10))
# Out:
# 20

# %%
# helper function
is_even = lambda x: x % 2 == 0

# test function
def sum_even(L):
    """ Calculates the sum of all even numbers in a list

    Args:
        L: a list of numbers

    Returns:
        the sum of all even numbers in a list after the condition of the helper function
        has been met.

    """
    output = sum([L for L in L[:] if is_even(L)])
    return output

def test_sum_even():
    assert sum_even([1,2]) == 2
    assert sum_even([1,2,3,4]) == 6
    assert sum_even(range(10)) == 20

test_sum_even()

# %% [markdown]
# ### <font color="red"> Exercise 3 </font>
#
# Write a function called `freq` that takes a value `a` and a list `L` as arguments and returns the number of times `a` occurs in `L`.
#
# **Example** `freq(1,[1,2,1,3,4]) == 2`
#
# **Hint** Use a filter in your comprehension and the `len` function

# %%
freq = lambda a, L: len([a for a in L[:] if ])

# %%
freq(1, [1,1,2,3,4])
# Out:
# 5

# %%
freq(2, [2,4,6,8,10,2])
# Out:
# 6

# %%
freq(3, [3,3,3,3,3])
# Out:
# 5

# %% [markdown]
# ### <font color="red"> Exercise 4 </font>
#
# Write a function called `between` that takes value `a`, `b` and a list `L` as arguments and returns `True` when all of the elements of `L` that strictly between `a` and `b`.
#
# **Example** `between(0, 5,[1,2,1,3,4]) == True`
#
# **Hint** Use a boolean expresion and the `all` function.

# %%
between = lambda a, b, L: [(a,b) for (a,b) in list(L) if (a < L < b)]

# %%
between(0, 5, [1,2,1,3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-151441d52dbe> in <module>()
# ----> 1 between(0, 5, [1,2,1,3,4])
#
# <ipython-input-51-442b405759f8> in <lambda>(a, b, L)
# ----> 1 between = lambda a, b, L: [(a,b) for (a,b) in list(L) if (a < L) and (L < b)]
#
# <ipython-input-51-442b405759f8> in <listcomp>(.0)
# ----> 1 between = lambda a, b, L: [(a,b) for (a,b) in list(L) if (a < L) and (L < b)]
#
# TypeError: 'int' object is not iterable
